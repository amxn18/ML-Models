# %%
import mlflow.pyfunc
import pandas as pd

MODEL_URI = "models:/titanic_survival_model@staging"

model = mlflow.pyfunc.load_model(MODEL_URI)

print("Model loaded from registry using alias")
# Out:
# Model loaded from registry using alias

# %%
X_test = pd.read_csv("../data/X_test.csv")
model.predict(X_test.head(5))
# Out:
# array([0, 0, 0, 0, 1])
